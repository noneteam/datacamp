# %% [markdown]
# # Loop over DataFrame (2)

# %% [markdown]
# #### EXERCISE:
# The row data that's generated by <code>iterrows()</code> on every run is a Pandas Series. This format is not very convenient to print out. Luckily, you can easily select variables from the Pandas Series using square brackets:
#
# <pre><code>for lab, row in brics.iterrows() :
#     print(row['country'])
# </code></pre>

# %% [markdown]
# #### INSTRUCTIONS:
# Adapt the code in the for loop such that the first iteration prints out <code>"US: 809"</code>, the second iteration <code>"AUS: 731"</code>, and so on. The output should be in the form <code>"country: cars_per_cap"</code>. Make sure to print out this exact string, with the correct spacing.

# %% [markdown]
# #### SCRIPT.PY:

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('../02-Dictionaries & Pandas/cars.csv', index_col = 0)

# Adapt for loop
for lab, row in cars.iterrows() :
    print(lab + ": " + str(row["cars_per_cap"]))
# Out:
# US: 809
# AUS: 731
# JAP: 588
# IN: 18
# RU: 200
# MOR: 70
# EG: 45
