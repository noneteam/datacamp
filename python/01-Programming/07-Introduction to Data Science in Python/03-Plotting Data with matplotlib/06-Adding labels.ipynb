# %% [markdown]
# # Adding labels

# %% [markdown]
# #### EXERCISE:
# If we give a chart with no labels to Officer Deshaun's supervisor, she won't know what the lines represent.
#
# We need to add labels to Officer Deshaun's plot of hours worked.

# %% [markdown]
# #### INSTRUCTIONS:
# * Add a descriptive title to the chart.
# * Add a label for the y-axis.

# %% [markdown]
# #### SCRIPT.PY:

# %%
# %matplotlib inline
import pandas as pd
from matplotlib import pyplot as plt
deshaun = pd.DataFrame([['M', 8], ['Tu', 5], ['W', 3], ['Th', 5], ['F', 8]],
                       columns=['day_of_week', 'hours_worked'])
mengfei = pd.DataFrame([['M', 0], ['Tu', 0], ['W', 5], ['Th', 9], ['F', 5]],
                       columns=['day_of_week', 'hours_worked'])
aditya = pd.DataFrame([['M', 10], ['Tu', 2], ['W', 1], ['Th', 0], ['F', 0]],
                       columns=['day_of_week', 'hours_worked'])
# Lines
plt.plot(deshaun.day_of_week, deshaun.hours_worked, label='Deshaun')
plt.plot(aditya.day_of_week, aditya.hours_worked, label='Aditya')
plt.plot(mengfei.day_of_week, mengfei.hours_worked, label='Mengfei')

# Add a title
plt.title("Officer, on the Missing Puppy Report for Bayes")

# Add y-axis label
plt.ylabel("Hours worked per Day")

# Legend
plt.legend()
# Display plot
plt.show()
